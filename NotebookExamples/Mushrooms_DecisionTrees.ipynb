# %% [markdown]
# # PoisonousMushrooms

# %% [markdown]
# "This data set includes descriptions of hypothetical samples corresponding to 23 species of gilled mushrooms in the Agaricus and Lepiota Family (pp. 500-525). Each species is identified as definitely edible, definitely poisonous, or of unknown edibility and not recommended. This latter class was combined with the poisonous one. The Guide clearly states that there is no simple rule for determining the edibility of a mushroom; no rule like ``leaflets three, let it be'' for Poisonous Oak and Ivy."
#
# _ source: http://archive.ics.uci.edu/ml/datasets/Mushroom _

# %% [markdown]
# The objective will be to create a rule based model combining different decisions to classify a mushroom on edible or poisonous. A Decision Tree classifier will be used to extract the rules.

# %% [markdown]
# Every row on the file looks like this:
# > p,x,s,n,t,p,f,c,n,k,e,e,s,s,w,w,p,w,o,p,k,s,u
#
# The first character is the status: poisonous(p) / edible(e), and the rest are the features, all of them categorical

# %% [markdown]
# #### Attribute Information:
#
# 1. cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s
# 2. cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s
# 3. cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r, pink=p,purple=u,red=e,white=w,yellow=y
# 4. bruises?: bruises=t,no=f
# 5. odor: almond=a,anise=l,creosote=c,fishy=y,foul=f, musty=m,none=n,pungent=p,spicy=s
# 6. gill-attachment: attached=a,descending=d,free=f,notched=n
# 7. gill-spacing: close=c,crowded=w,distant=d
# 8. gill-size: broad=b,narrow=n
# 9. gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e, white=w,yellow=y
# 10. stalk-shape: enlarging=e,tapering=t
# 11. stalk-root: bulbous=b,club=c,cup=u,equal=e, rhizomorphs=z,rooted=r,missing=?
# 12. stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s
# 13. stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s
# 14. stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o, pink=p,red=e,white=w,yellow=y
# 15. stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o, pink=p,red=e,white=w,yellow=y
# 16. veil-type: partial=p,universal=u
# 17. veil-color: brown=n,orange=o,white=w,yellow=y
# 18. ring-number: none=n,one=o,two=t
# 19. ring-type: cobwebby=c,evanescent=e,flaring=f,large=l, none=n,pendant=p,sheathing=s,zone=z
# 20. spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r, orange=o,purple=u,white=w,yellow=y
# 21. population: abundant=a,clustered=c,numerous=n, scattered=s,several=v,solitary=y
# 22. habitat: grasses=g,leaves=l,meadows=m,paths=p, urban=u,waste=w,woods=d
#
# _ source: http://archive.ics.uci.edu/ml/datasets/Mushroom _

# %% [markdown]
# Importing the file. Pandas wil be used to manage the data.

# %%
import pandas
#md: mushrooms data
md = pandas.read_csv("F:/Datasets/agaricus-lepiota.data", header=None, 
                     names=["edibility", "cap-shape", "cap-surface", "cap-color", "bruises", "odor", "gill-attachment", "gill-spacing", "gill-size", "gill-color", "stalk-shape", "stalk-root", "stalk-surface-above-ring", "stalk-surface-below-ring", "stalk-color-above-ring", "stalk-color-below-ring", "veil-type", "veil-color", "ring-number", "ring-type", "spore-print-color", "population", "habitat"])

# %%
md.tail()
# Out:
#      edibility cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 8119         e         k           s         n       f    n               a
# 8120         e         x           s         n       f    n               a
# 8121         e         f           s         n       f    n               a
# 8122         p         k           y         n       f    y               f
# 8123         e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 8119            c         b          y   ...                          s
# 8120            c         b          y   ...                          s
# 8121            c         b          n   ...                          s
# 8122            c         n          b   ...                          k
# 8123            c         b          y   ...                          s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %% [markdown]
# ### Data Visualization

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %% [markdown]
# Edibility:

# %%
mpl.rcParams['figure.figsize'] = (8, 6)
sns.countplot(x="edibility", data=md);

# %% [markdown]
# Relations of the Features with the edibility:

# %%
mpl.rcParams['figure.figsize'] = (16, 6)
plt.figure(1)
plt.subplot(131)
sns.countplot(x="cap-shape", hue="edibility", data=md)
plt.subplot(132)
sns.countplot(x="cap-surface", hue="edibility", data=md)
plt.subplot(133)
sns.countplot(x="cap-color", hue="edibility", data=md)

# %%
plt.figure(1)
plt.subplot(131)
sns.countplot(x="bruises", hue="edibility", data=md)
plt.subplot(132)
sns.countplot(x="odor", hue="edibility", data=md)
plt.subplot(133)
sns.countplot(x="gill-attachment", hue="edibility", data=md)

# %%
plt.figure(1)
plt.subplot(131)
sns.countplot(x="gill-spacing", hue="edibility", data=md)
plt.subplot(132)
sns.countplot(x="gill-size", hue="edibility", data=md)
plt.subplot(133)
sns.countplot(x="gill-color", hue="edibility", data=md)

# %%
plt.figure(1)
plt.subplot(131)
sns.countplot(x="stalk-shape", hue="edibility", data=md)
plt.subplot(132)
sns.countplot(x="stalk-root", hue="edibility", data=md)
plt.subplot(133)
sns.countplot(x="stalk-surface-above-ring", hue="edibility", data=md)

# %%
plt.figure(1)
plt.subplot(131)
sns.countplot(x="stalk-surface-below-ring", hue="edibility", data=md)
plt.subplot(132)
sns.countplot(x="stalk-color-above-ring", hue="edibility", data=md)
plt.subplot(133)
sns.countplot(x="stalk-color-below-ring", hue="edibility", data=md)

# %%
plt.figure(1)
plt.subplot(131)
sns.countplot(x="veil-type", hue="edibility", data=md)
plt.subplot(132)
sns.countplot(x="veil-color", hue="edibility", data=md)
plt.subplot(133)
sns.countplot(x="ring-number", hue="edibility", data=md)

# %%
plt.figure(1)
plt.subplot(121)
sns.countplot(x="ring-type", hue="edibility", data=md)
plt.subplot(122)
sns.countplot(x="spore-print-color", hue="edibility", data=md)

# %%
plt.figure(1)
plt.subplot(121)
sns.countplot(x="population", hue="edibility", data=md)
plt.subplot(122)
sns.countplot(x="habitat", hue="edibility", data=md)

# %% [markdown]
# Some conclusions from the visualization:
#     - the feature veil-type only contain one value, so it could be removed
#     - there are a few obvious rules than can be found, where the is a big difference between poisonous and edible on some classes, like the mushrooms is poisonous if:
#         - if bruises is false
#         - if odor is f,c,y,s or m
#         - if gill-size is n(narrow)
#         - if gill-color is b(buff)
#         - if population is v(several)
#         and so on

# %% [markdown]
# The idea is for a C4.5 decision tree to find all or most of these rules and combinations

# %%
edibility = md["edibility"]

# %%
del(md["edibility"])

# %% [markdown]
# Creation of dummy variables, to enconde the categorical variables:

# %%
md_encoded = pandas.get_dummies(md)

# %%
md_encoded.tail()
# Out:
#       cap-shape_b  cap-shape_c  cap-shape_f  cap-shape_k  cap-shape_s  \
# 8119            0            0            0            1            0
# 8120            0            0            0            0            0
# 8121            0            0            1            0            0
# 8122            0            0            0            1            0
# 8123            0            0            0            0            0
#
#       cap-shape_x  cap-surface_f  cap-surface_g  cap-surface_s  cap-surface_y  \
# 8119            0              0              0              1              0
# 8120            1              0              0              1              0
# 8121            0              0              0              1              0
# 8122            0              0              0              0              1
# 8123            1              0              0              1              0
#
#         ...      population_s  population_v  population_y  habitat_d  \
# ...

# %% [markdown]
# Creation of the testing set, to check the trained model on different data:

# %%
import sklearn.cross_validation
md_train, md_test, ed_train, ed_test = sklearn.cross_validation.train_test_split(md_encoded, edibility, test_size = 0.333)

# %% [markdown]
# The tree:

# %%
from sklearn import tree
md_tree = tree.DecisionTreeClassifier()

# %%
md_tree.fit(md_train, ed_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %% [markdown]
# Testing the tree:

# %%
ed_prediction = md_tree.predict(md_test)

# %%
from sklearn import metrics
score = metrics.accuracy_score(ed_test, ed_prediction)

# %%
score
# Out:
# 1.0

# %% [markdown]
# A perfect score! So it is possible to create a decision tree to perfectly classify mushrooms in edible and poisonous based on physical characteristics

# %% [markdown]
# It is possible to visualize the tree, following the instructions on the scikit-learn Decision Trees page

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image

# %%
dot_data = StringIO()  
tree.export_graphviz(md_tree, out_file=dot_data, feature_names=md_encoded.columns, class_names=list(md_tree.classes_), 
                     filled=True, rounded=True, impurity=False, special_characters=True)

# %%
#It is necessary to install GraphViz and pydot-ng first
import pydot_ng as pydot
graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# In this tree blue labels are poisonous and red are edible, and <= 0.5 indicates absence of the especific class.

# %% [markdown]
# This representation could be used by a human on the field to decide if some mushroom is edible or poisonous, although given the risk it is not recommended to actualy eat it if the user don't have experience with mushrooms
